# %% [markdown]
# <a href="https://colab.research.google.com/github/dakilaledesma/669_Final_Project/blob/main/669_Fishbase_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Copying datasets
! mkdir data
! cp "drive/MyDrive/UNC/Classes/BIOL 669/fishbase_iucn.csv" data/fishbase_iucn.csv
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
#@title Ignoring all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#@title Training a model to see which columns have useful information
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import pandas as pd
import numpy as np

iucn_data = pd.read_csv("data/fishbase_iucn.csv")
labels = iucn_data["redlistCategory"].str.lower()
label_mapping = {}
for y_cat in labels:
    if y_cat not in label_mapping.keys():
      label_mapping[y_cat] = len(label_mapping.values())

print(label_mapping.items())

train_columns = [c for c in iucn_data.columns if c not in ["specCode", "scientificName", "redlistCategory"]]
for t in train_columns:
  xy = iucn_data[[t, "redlistCategory"]]
  # xy = xy[xy["redlistCategory"].str.lower() != "least concern"]
  xy = xy.dropna()
  X = xy[t]
  y = []
  for label in list(xy['redlistCategory'].str.lower()):
    y_arr = np.zeros((len(label_mapping.values())))
    y_arr[label_mapping.get(label)] = 1
    y.append(y_arr)
  y = np.array(y)

  try:
    num_classes = y.shape[1]
  except IndexError:
    continue

  model = Sequential()
  model.add(Dense(1, input_shape=(1,), activation='relu'))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  try:
    history = model.fit(X, y, epochs=20, batch_size=8, verbose=0, validation_split=0.2)
  except:
    continue
  print(f"{t}: {max(history.history['val_accuracy'])}")
# Out:
# dict_items([('least concern', 0), ('data deficient', 1), ('vulnerable', 2), ('not applicable', 3), ('endangered', 4), ('near threatened', 5), ('critically endangered', 6), ('regionally extinct', 7), ('lower risk/least concern', 8), ('extinct', 9), ('extinct in the wild', 10), ('lower risk/near threatened', 11)])
# SpecCode: 0.7243391871452332
# SpeciesRefNo: 0.7243391871452332

# %%
#@title From the above analysis we can ascertain that the following are the useful columns
useful_cols = ["DepthRangeShallow", "DepthRangeDeep", "DepthRangeComShallow", "DepthRangeComDeep", "DepthComRef", "LongevityWild", "LongevityCaptive", "Length", "LengthFemale", "CommonLength", "CommonLengthF", "Weight", "WeightFemale"]

# %%
#@title Defining the multi-layer perceptron model and turning it into a function to save space
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import pandas as pd
import numpy as np

def teh_nn(coi, incl_lc=True, num_layers=10, e=100, bs=8, vs=0.2):
  iucn_data = pd.read_csv("data/fishbase_iucn.csv")
  labels = iucn_data["redlistCategory"].str.lower()
  label_mapping = {}
  for y_cat in labels:
      if y_cat not in label_mapping.keys():
        label_mapping[y_cat] = len(label_mapping.values())

  xy = iucn_data[coi + ["redlistCategory"]]
  if not incl_lc:
    xy = xy[xy["redlistCategory"].str.lower() != "least concern"]
  xy = xy.dropna()
  X = xy[coi]
  y = []
  for label in list(xy['redlistCategory'].str.lower()):
    y_arr = np.zeros((len(label_mapping.values())))
    y_arr[label_mapping.get(label)] = 1
    y.append(y_arr)
  y = np.array(y)

  num_classes = y.shape[1]
  num_inputs = X.shape[1]

  model = Sequential()
  model.add(Dense(num_inputs, input_shape=(num_inputs,), activation='relu'))
  for n in range(num_layers):
    model.add(Dense(50, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  history = model.fit(X, y, epochs=e, batch_size=bs, verbose=0, validation_split=vs)
  # print(f"Samples: {y.shape[0]} Acc: {max(history.history['val_accuracy'])}")
  return max(history.history['val_accuracy'])

# %%
#@title Making all column combinations for brute force checking and some helper functions
from itertools import combinations
from collections import OrderedDict
from tqdm import tqdm

col_combinations = sum([list(map(list, combinations(useful_cols, i))) for i in range(len(useful_cols) + 1)], [])
col_combinations.remove([])

def print_dict(dct):
    for k, v in list(dct.items())[:500]:  
        print(f"{k}: {v}")

# %%
#@title Brute force column combination accuracy checking (without least concern species)
acc_dict_lcf = {}
for coi in tqdm([[]]):
  try:
    coi_acc = teh_nn(coi, e=10, incl_lc=False)
  except:
    continue
  str_coi = ', '.join(coi)
  acc_dict_lcf[str_coi] = coi_acc

o_acc_dict_lcf = OrderedDict(sorted(acc_dict_lcf.items(), key=lambda t: t[1], reverse=True))
print_dict(o_acc_dict_lcf)
# Out:
# 100%|██████████| 8191/8191 [1:50:51<00:00,  1.23it/s]
# DepthRangeComDeep, CommonLengthF: 1.0
# DepthComRef, CommonLengthF: 1.0
# LongevityCaptive, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, WeightFemale: 1.0
# DepthRangeComShallow, Length, WeightFemale: 1.0
# DepthRangeComShallow, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, CommonLength, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, CommonLengthF: 1.0
# DepthRangeComDeep, LongevityWild, WeightFemale: 1.0
# DepthRangeComDeep, Length, CommonLengthF: 1.0
# DepthRangeComDeep, LengthFemale, CommonLengthF: 1.0
# DepthRangeComDeep, CommonLength, CommonLengthF: 1.0
# DepthRangeComDeep, Weight, WeightFemale: 1.0
# DepthComRef, LongevityWild, WeightFemale: 1.0
# DepthComRef, Length, CommonLengthF: 1.0
# DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthComRef, CommonLength, CommonLengthF: 1.0
# DepthComRef, Weight, WeightFemale: 1.0
# LongevityWild, CommonLengthF, WeightFemale: 1.0
# LongevityWild, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLengthF: 1.0
# LongevityCaptive, Length, WeightFemale: 1.0
# LongevityCaptive, CommonLength, CommonLengthF: 1.0
# LongevityCaptive, CommonLength, WeightFemale: 1.0
# LongevityCaptive, CommonLengthF, Weight: 1.0
# LongevityCaptive, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, Weight, WeightFemale: 1.0
# Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeShallow, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, Length, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, CommonLength, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, Length, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeComShallow, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, Length, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, CommonLength, CommonLengthF: 1.0
# DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthComRef, Length, CommonLength, CommonLengthF: 1.0
# DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLengthF: 1.0
# LongevityWild, LongevityCaptive, Length, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# LongevityWild, Length, CommonLengthF, WeightFemale: 1.0
# LongevityWild, Length, Weight, WeightFemale: 1.0
# LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# LongevityCaptive, Length, Weight, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# Length, CommonLength, Weight, WeightFemale: 1.0
# LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, Length, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, Length, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, Length, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, Length, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, Length, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, Length, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, LengthFemale, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, Length, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, Length, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, CommonLength, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Length, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, CommonLength, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeComShallow, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LongevityCaptive, Length, LengthFemale, Weight: 1.0
# DepthRangeComShallow, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeComDeep, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, Length, CommonLength, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityCaptive, Length, LengthFemale, Weight: 1.0
# DepthRangeComDeep, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeComDeep, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthComRef, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# LongevityWild, LongevityCaptive, Length, LengthFemale, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLength, CommonLengthF: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityWild, Length, LengthFemale, Weight, WeightFemale: 1.0
# LongevityWild, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLength, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLength, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLength, Weight, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# Length, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LengthFemale, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, Length, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, Length, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, Length, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, Length, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, Length, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, Length, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LengthFemale, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, LongevityWild, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, Length, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, Length, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LengthFemale, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LongevityWild, LongevityCaptive, Weight: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, Length, CommonLength, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityCaptive, Length, LengthFemale, CommonLength: 1.0
# DepthRangeComShallow, DepthRangeComDeep, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthComRef, LongevityWild, Length, LengthFemale, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# LongevityWild, LongevityCaptive, Length, LengthFemale, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLength, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLength, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLength, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityWild, Length, LengthFemale, CommonLength, CommonLengthF, Weight: 1.0
# LongevityWild, Length, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, Length, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLength, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# Length, LengthFemale, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0

# %%
#@title Brute force column combination accuracy checking (with least concern species)
acc_dict_lct = {}
for coi in tqdm(col_combinations):
  try:
    coi_acc = teh_nn(coi, e=10, incl_lc=True)
  except:
    continue
  str_coi = ', '.join(coi)
  acc_dict_lct[str_coi] = coi_acc

o_acc_dict_lct = OrderedDict(sorted(acc_dict_lct.items(), key=lambda t: t[1], reverse=True))
print_dict(o_acc_dict_lct)
# Out:
# 100%|██████████| 8191/8191 [2:28:13<00:00,  1.09s/it]
# DepthRangeShallow, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeShallow, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeComShallow, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeComDeep, LongevityCaptive, LengthFemale: 1.0
# DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthComRef, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLengthF: 1.0
# LongevityCaptive, CommonLength, CommonLengthF: 1.0
# LongevityCaptive, CommonLength, WeightFemale: 1.0
# LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, CommonLengthF, Weight: 1.0
# DepthRangeDeep, DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeComShallow, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeComShallow, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeComShallow, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeComShallow, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, Length, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeComDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeComDeep, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeComDeep, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeComDeep, LongevityWild, CommonLength, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeComDeep, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeComDeep, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeComDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, CommonLength, Weight, WeightFemale: 1.0
# DepthComRef, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthComRef, LongevityCaptive, Length, LengthFemale: 1.0
# DepthComRef, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthComRef, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# LongevityWild, Length, LengthFemale, CommonLengthF: 1.0
# LongevityWild, LengthFemale, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# LongevityCaptive, Length, LengthFemale, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLength, CommonLengthF: 1.0
# LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthComRef, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthComRef, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthComRef, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, Length, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComShallow, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComShallow, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, DepthComRef, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeDeep, DepthRangeComDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthRangeComDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeDeep, DepthComRef, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeDeep, DepthComRef, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeDeep, DepthComRef, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, DepthComRef, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeDeep, DepthComRef, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityWild, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeDeep, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, Length, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthRangeComDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeComShallow, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, DepthComRef, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, DepthComRef, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, DepthComRef, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeComShallow, LongevityWild, Length, LengthFemale, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeComShallow, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LongevityWild, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeComShallow, LongevityCaptive, LengthFemale, CommonLength, Weight: 1.0
# DepthRangeComShallow, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComShallow, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeComDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeComDeep, DepthComRef, Length, CommonLengthF, Weight: 1.0
# DepthRangeComDeep, DepthComRef, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityWild, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeComDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeComDeep, LongevityWild, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeComDeep, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, LongevityCaptive, Length, LengthFemale, CommonLength: 1.0
# DepthRangeComDeep, LongevityCaptive, Length, LengthFemale, Weight: 1.0
# DepthRangeComDeep, LongevityCaptive, LengthFemale, CommonLength, Weight: 1.0
# DepthRangeComDeep, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeComDeep, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeComDeep, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthComRef, LongevityWild, LongevityCaptive, Length, LengthFemale: 1.0
# DepthComRef, LongevityWild, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthComRef, LongevityWild, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthComRef, LongevityWild, Length, CommonLength, CommonLengthF: 1.0
# DepthComRef, LongevityWild, Length, CommonLength, WeightFemale: 1.0
# DepthComRef, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthComRef, LongevityCaptive, Length, LengthFemale, CommonLength: 1.0
# DepthComRef, LongevityCaptive, Length, LengthFemale, Weight: 1.0
# DepthComRef, LongevityCaptive, LengthFemale, CommonLength, Weight: 1.0
# DepthComRef, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthComRef, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthComRef, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# LongevityWild, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# LongevityWild, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityWild, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# LongevityWild, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityWild, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight: 1.0
# LongevityCaptive, Length, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLength, Weight, WeightFemale: 1.0
# LongevityCaptive, Length, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, Weight: 1.0
# LongevityCaptive, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLength, Weight, WeightFemale: 1.0
# LongevityCaptive, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# LongevityCaptive, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# Length, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# Length, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthRangeComDeep, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComShallow, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthRangeComDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, DepthComRef, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, Length, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, LengthFemale, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, LongevityCaptive, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityWild, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeDeep, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, DepthComRef, LongevityWild, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, DepthComRef, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, DepthComRef, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthRangeComDeep, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, Length, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, DepthComRef, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LongevityWild, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComShallow, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComShallow, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityWild, Length, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityWild, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityWild, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, DepthComRef, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityWild, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, Length, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, Length, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, LongevityCaptive, LengthFemale, CommonLength, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthRangeComDeep, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthRangeComDeep, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LongevityCaptive, Length, LengthFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LongevityCaptive, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, Length, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityWild, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, Length, LengthFemale, CommonLength: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, Length, LengthFemale, Weight: 1.0
# DepthRangeShallow, DepthComRef, LongevityCaptive, LengthFemale, CommonLength, Weight: 1.0
# DepthRangeShallow, DepthComRef, Length, LengthFemale, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, Length, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, DepthComRef, Length, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, DepthComRef, LengthFemale, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, LengthFemale, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, Length, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, LengthFemale, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLength, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LongevityCaptive, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, Length, LengthFemale, CommonLength, CommonLengthF: 1.0
# DepthRangeShallow, LongevityWild, Length, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, LengthFemale, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityWild, CommonLength, CommonLengthF, Weight, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, LengthFemale, CommonLength, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, LengthFemale, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, CommonLengthF, Weight: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, CommonLengthF, WeightFemale: 1.0
# DepthRangeShallow, LongevityCaptive, Length, CommonLength, Weight, WeightFemale: 1.0

# %%
#@title Depth ranges with least concern categories
#@markdown Acc: 81.63%
cols_of_interest = ["DepthRangeShallow", "DepthRangeDeep", "DepthRangeComShallow", "DepthRangeComDeep", "DepthComRef"]
teh_nn(cols_of_interest, incl_lc=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
# Samples: 1770 Acc: 0.8163841962814331

# %%
#@title Depth ranges without least concern categories
#@markdown Acc: 33.76%
cols_of_interest = ["DepthRangeShallow", "DepthRangeDeep", "DepthRangeComShallow", "DepthRangeComDeep", "DepthComRef"]
teh_nn(cols_of_interest, incl_lc=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
# Samples: 383 Acc: 0.33766233921051025

# %%
#@title Longevities with least concern categories
#@markdown Acc: 79.17%
cols_of_interest = ["LongevityWild", "LongevityCaptive"]
teh_nn(cols_of_interest, incl_lc=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
# Samples: 120 Acc: 0.7916666865348816

# %%
#@title Longevities without least concern categories, highly variable acc depending on validation split seed
#@markdown Acc: 62.5%
cols_of_interest = ["LongevityWild", "LongevityCaptive"]
teh_nn(cols_of_interest, incl_lc=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Samples: 39 Acc: 0.625

# %%
#@title Length with least concern categories
#@markdown Acc: 80.00%
cols_of_interest = ["Length", "LengthFemale", "CommonLength", "CommonLengthF"]
teh_nn(cols_of_interest, incl_lc=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   after removing the cwd from sys.path.
# Samples: 24 Acc: 0.800000011920929

# %%
#@title Length without least concern categories
#@markdown Acc: Untested%
cols_of_interest = ["Length", "LengthFemale", "CommonLength", "CommonLengthF"]
teh_nn(cols_of_interest, incl_lc=False)

# %%
#@title Longevities without least concern categories, highly variable acc depending on validation split seed
#@markdown Acc: 75%
cols_of_interest = ["LongevityWild", "LongevityCaptive"]
teh_nn(cols_of_interest, incl_lc=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   after removing the cwd from sys.path.
# 0.75
